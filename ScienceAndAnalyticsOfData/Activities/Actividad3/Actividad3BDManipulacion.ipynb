# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 3**
# Bases, almacenes y manipulación de datos
#
# ---

# %% [markdown]
# *   NOMBRE: Isaac Carballo Perez
# *   MATRÍCULA: A01796987

# %% [markdown]
# ---

# %% [markdown]
# En esta actividad usarás la base de datos relacional `classicmodels` (MySQL), compuesta por las siguientes tablas:
#
# *   `Customers`: almacena los datos de los clientes.
# *   `Products`: almacena una lista de modelos de coches a escala.
# *   `ProductLines`: almacena una lista de categorías de líneas de productos.
# *   `Orders`: almacena los pedidos de venta realizados por los clientes.
# *   `OrderDetails`: almacena elementos de línea de pedidos de ventas para cada pedido de ventas.
# *   `Payments`: almacena los pagos realizados por los clientes en función de sus cuentas.
# *   `Employees`: almacena toda la información de los empleados, así como la estructura de la organización, como quién informa a quién.
# *   `Offices`: almacena los datos de la oficina de ventas.
#
# Revisa con detalle su esquema para que comprendas cómo se relacionan las tablas anteriores.

# %% [markdown]
# Recuerda que:
#
#
# *   Una **clave primaria** es un atributo (o conjunto) que identifica unívocamente a cada registro en la tabla.
# *   Una **clave foránea** (externa o ajena) es un atributos (o conjunto) en una tabla que es una clave primaria en otra (o posiblemente la misma) tabla.
# *   Las **relaciones** son las líneas que conectan una tabla con otra y el extremo determina la cardinalidad. Las relaciones con línea continua (identificadora) representan una transformación donde la clave primaria de una tabla pasa a ser foránea y primaria (al mismo tiempo) de otra. Las relaciones con línea discontinua (no identificadora) representan una transformación donde la clave primaria de una tabla pasa a ser sólo foránea en otra.

# %% [markdown]
# # **Parte 1**. SQLAlchemy y SQL básico

# %%
pip install pymysql

# %%
import sqlalchemy as sqla
import pymysql
import pandas as pd

# %% [markdown]
# 1.	Crea el motor `sqlalchemy`, con el método `create_engine()` y una conexión con `connect()` como se muestra a continuación:

# %%
# Crear el motor (dialecto://usuarioBD:clave@ipHostDBMS:puerto/esquema
db = sqla.create_engine('mysql+pymysql://mnaTC4029User:mnaTC4029Pass!@20.106.217.214:3306/classicmodels', pool_recycle=3600)

# Crea una conexión para luego invocar declaraciones SQL
conn = db.connect()

# %% [markdown]
# Escribe las consultas en SQL para obtener:

# %% [markdown]
# 2.	La información de las líneas de productos.

# %%
query = sqla.text('SELECT * FROM productlines')
pd.read_sql_query(query, conn)
# Out:
#         productLine                                    textDescription  \
# 0      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1       Motorcycles  Our motorcycles are state of the art replicas ...
# 2            Planes  Unique, diecast airplane and helicopter replic...
# 3             Ships  The perfect holiday or anniversary gift for ex...
# 4            Trains  Model trains are a rewarding hobby for enthusi...
# 5  Trucks and Buses  The Truck and Bus models are realistic replica...
# 6      Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmlDescription image
# 0            None  None
# 1            None  None
# 2            None  None
# 3            None  None
# 4            None  None
# 5            None  None
# 6            None  None

# %% [markdown]
# 3.	La información de los empleados ordenados por nombre (`firstName`).

# %%
query = sqla.text('SELECT * FROM employees ORDER BY firstName')
pd.read_sql_query(query, conn)
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1611     Fixter      Andy      x101
# 1             1143        Bow   Anthony     x5428
# 2             1504      Jones     Barry      x102
# 3             1002     Murphy     Diane     x5800
# 4             1286      Tseng  Foon Yue     x2248
# 5             1323     Vanauf    George     x4102
# 6             1102     Bondur    Gerard     x5408
# 7             1370  Hernandez    Gerard     x2028
# 8             1076   Firrelli      Jeff     x9273
# 9             1188   Firrelli     Julie     x2173
# 10            1501       Bott     Larry     x2311
# 11            1165   Jennings    Leslie     x3291
# 12            1166   Thompson    Leslie     x4065
# 13            1337     Bondur      Loui     x6493
# 14            1621      Nishi      Mami      x101
# 15            1702     Gerard    Martin     x2312
# 16            1056  Patterson      Mary     x4611
# 17            1401   Castillo    Pamela     x2759
# ...

# %% [markdown]
# 4.	Los países donde hay oficinas (sin duplicar).

# %%
query = sqla.text('SELECT DISTINCT country FROM offices')
pd.read_sql_query(query, conn)
# Out:
#      country
# 0        USA
# 1     France
# 2      Japan
# 3  Australia
# 4         UK

# %% [markdown]
# 5.	El nombre y teléfono de los clientes de la ciudad de Nueva York (*NYC*).

# %%
query = sqla.text('SELECT customerName, phone FROM customers WHERE city LIKE "NYC"')
pd.read_sql_query(query, conn)
# Out:
#            customerName       phone
# 0     Land of Toys Inc.  2125557818
# 1    Muscle Machine Inc  2125557413
# 2       Vitachrome Inc.  2125551500
# 3  Classic Legends Inc.  2125558493
# 4       Microscale Inc.  2125551957

# %% [markdown]
# 6.	El código y nombre de los productos del vendedor *Gearbox Collectibles* que tengan menos de 1000 unidades en stock.

# %%
query = sqla.text('SELECT productCode, productName from products WHERE productVendor LIKE "Gearbox Collectibles" AND quantityInStock < 1000')
pd.read_sql_query(query, conn)
# Out:
#   productCode             productName
# 0    S18_2581          P-51-D Mustang
# 1    S18_2795  1928 Mercedes-Benz SSK

# %% [markdown]
# 7.	Los tres productos más caros, desde el punto de visto de los comercializadores (`buyPrice`).

# %%
query = sqla.text('SELECT * FROM products ORDER BY -buyPrice LIMIT 3')
pd.read_sql_query(query, conn)
# Out:
#   productCode                     productName   productLine productScale  \
# 0    S10_4962          1962 LanciaA Delta 16V  Classic Cars         1:10
# 1    S18_2238  1998 Chrysler Plymouth Prowler  Classic Cars         1:18
# 2    S10_1949        1952 Alpine Renault 1300  Classic Cars         1:10
#
#              productVendor                                 productDescription  \
# 0      Second Gear Diecast  Features include: Turnable front wheels; steer...
# 1     Gearbox Collectibles  Turnable front wheels; steering function; deta...
# 2  Classic Metal Creations  Turnable front wheels; steering function; deta...
#
#    quantityInStock  buyPrice    MSRP
# 0             6791    103.42  147.74
# 1             4724    101.51  163.73
# 2             7305     98.58  214.30

# %% [markdown]
# 8.	La cantidad de productos por línea de producto (no las existencias en inventario)

# %%
query = sqla.text('SELECT productLine, COUNT(productCode) as "#products" FROM products GROUP BY productLine')
pd.read_sql_query(query, conn)
# Out:
#         productLine  #products
# 0      Classic Cars         38
# 1       Motorcycles         13
# 2            Planes         12
# 3             Ships          9
# 4            Trains          3
# 5  Trucks and Buses         11
# 6      Vintage Cars         24

# %% [markdown]
# 9.	La cantidad de empleados por país (tomando en cuenta la ubicación de la oficina).

# %%
query = sqla.text('SELECT country, COUNT(employeeNumber) as "#employees" FROM employees INNER JOIN offices ON employees.officeCode = offices.officeCode GROUP BY country')
pd.read_sql_query(query, conn)
# Out:
#      country  #employees
# 0  Australia           4
# 1     France           5
# 2      Japan           2
# 3         UK           2
# 4        USA          10

# %% [markdown]
# 10.	El promedio de los pagos de cada uno de los clientes de España (sin incluir aquellos que no poseen ningún pago).

# %%
# INNER JOIN: This correctly joins the customers and payments tables based on the customerNumber, ensuring that only customers with payments are included.
query = sqla.text('SELECT customerName, AVG(amount) FROM customers INNER JOIN payments ON customers.customerNumber = payments.customerNumber WHERE customers.country LIKE "SPAIN" GROUP BY customerName')
pd.read_sql_query(query, conn)
# Out:
#                  customerName   AVG(amount)
# 0                 CAF Imports  23375.570000
# 1  Corrida Auto Replicas, Ltd  37480.030000
# 2          Enaco Distributors  22840.156667
# 3      Euro+ Shopping Channel  55056.844615
# 4  Iberia Gift Imports, Corp.  25493.925000

# %% [markdown]
# # **Parte 2**. Manipulación de datos con Pandas

# %% [markdown]
# 11.	Carga las tablas empleadas en dataframes con el mismo nombre y resuelve las consultas anteriores con las funciones de Pandas (NO con SQL). Cuida no sobreescribir los dataframes originales al resolver las consultas. Debes obtener los mismos resultados que con SQL.

# %%
product_lines_df = pd.read_sql_table('productlines', conn)
products_df = pd.read_sql_table('products', conn)
order_details_df = pd.read_sql_table('orderdetails', conn)
orders_df = pd.read_sql_table('orders', conn)
customers_df = pd.read_sql_table('customers', conn)
employees_df = pd.read_sql_table('employees', conn)
offices_df = pd.read_sql_table('offices', conn)
payments_df = pd.read_sql_table('payments', conn)

# %% [markdown]
# Información de las líneas de productos.

# %%
product_lines_df
# Out:
#         productLine                                    textDescription  \
# 0      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1       Motorcycles  Our motorcycles are state of the art replicas ...
# 2            Planes  Unique, diecast airplane and helicopter replic...
# 3             Ships  The perfect holiday or anniversary gift for ex...
# 4            Trains  Model trains are a rewarding hobby for enthusi...
# 5  Trucks and Buses  The Truck and Bus models are realistic replica...
# 6      Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmlDescription image
# 0            None  None
# 1            None  None
# 2            None  None
# 3            None  None
# 4            None  None
# 5            None  None
# 6            None  None

# %% [markdown]
# La información de los empleados ordenados por nombre (firstName).

# %%
employees_df.sort_values(by="firstName", ignore_index=True)
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1611     Fixter      Andy      x101
# 1             1143        Bow   Anthony     x5428
# 2             1504      Jones     Barry      x102
# 3             1002     Murphy     Diane     x5800
# 4             1286      Tseng  Foon Yue     x2248
# 5             1323     Vanauf    George     x4102
# 6             1370  Hernandez    Gerard     x2028
# 7             1102     Bondur    Gerard     x5408
# 8             1076   Firrelli      Jeff     x9273
# 9             1188   Firrelli     Julie     x2173
# 10            1501       Bott     Larry     x2311
# 11            1165   Jennings    Leslie     x3291
# 12            1166   Thompson    Leslie     x4065
# 13            1337     Bondur      Loui     x6493
# 14            1621      Nishi      Mami      x101
# 15            1702     Gerard    Martin     x2312
# 16            1056  Patterson      Mary     x4611
# 17            1401   Castillo    Pamela     x2759
# ...

# %% [markdown]
# Los países donde hay oficinas (sin duplicar).

# %%
country_offices = offices_df.loc[:, ["country"]].drop_duplicates(ignore_index=True)
country_offices
# Out:
#      country
# 0        USA
# 1     France
# 2      Japan
# 3  Australia
# 4         UK

# %% [markdown]
# El nombre y teléfono de los clientes de la ciudad de Nueva York (NYC).

# %%
# reset_index(drop=True): The reset_index() method is used to reset the index of a DataFrame. Setting drop=True prevents the old index from being added as a column, effectively ignoring the previous index
customers_ny = customers_df.loc[customers_df.city == "NYC", ["customerName", "phone"]].reset_index(drop=True)
customers_ny
# Out:
#            customerName       phone
# 0     Land of Toys Inc.  2125557818
# 1    Muscle Machine Inc  2125557413
# 2       Vitachrome Inc.  2125551500
# 3  Classic Legends Inc.  2125558493
# 4       Microscale Inc.  2125551957

# %% [markdown]
# El código y nombre de los productos del vendedor Gearbox Collectibles que tengan menos de 1000 unidades en stock.

# %%
gearbox_df = products_df.loc[(products_df.productVendor.str.contains("Gearbox Collectibles", na=False, case=False)) & (products_df.quantityInStock < 1000), ["productCode", "productName"]].reset_index(drop=True)
gearbox_df
# Out:
#   productCode             productName
# 0    S18_2581          P-51-D Mustang
# 1    S18_2795  1928 Mercedes-Benz SSK

# %% [markdown]
# Los tres productos más caros, desde el punto de visto de los comercializadores (buyPrice).

# %%
three_most_expensive_df = products_df.sort_values(by="buyPrice", ascending=False).head(3).reset_index(drop=True)
three_most_expensive_df
# Out:
#   productCode                     productName   productLine productScale  \
# 0    S10_4962          1962 LanciaA Delta 16V  Classic Cars         1:10
# 1    S18_2238  1998 Chrysler Plymouth Prowler  Classic Cars         1:18
# 2    S10_1949        1952 Alpine Renault 1300  Classic Cars         1:10
#
#              productVendor                                 productDescription  \
# 0      Second Gear Diecast  Features include: Turnable front wheels; steer...
# 1     Gearbox Collectibles  Turnable front wheels; steering function; deta...
# 2  Classic Metal Creations  Turnable front wheels; steering function; deta...
#
#    quantityInStock  buyPrice    MSRP
# 0             6791    103.42  147.74
# 1             4724    101.51  163.73
# 2             7305     98.58  214.30

# %% [markdown]
# La cantidad de productos por línea de producto (no las existencias en inventario)

# %%
num_products_df = products_df.groupby("productLine")['productCode'].count().reset_index().rename(columns={'productCode': '#products'})
num_products_df
# Out:
#         productLine  #products
# 0      Classic Cars         38
# 1       Motorcycles         13
# 2            Planes         12
# 3             Ships          9
# 4            Trains          3
# 5  Trucks and Buses         11
# 6      Vintage Cars         24

# %% [markdown]
# La cantidad de empleados por país (tomando en cuenta la ubicación de la oficina).

# %%
# employees_per_country_df = employees_df.merge(offices_df, left_on="officeCode", right_on="officeCode", how="inner").groupby("country")['employeeNumber'].count().reset_index().rename(columns={'employeeNumber': '#employees'})
# The prior code is equivalent to the one in the following line since by default when doing a merge the join is inner join and the column that is used to merge is the one that has the same name on both dataframes which in this case is 'officeCode'
employees_per_country_df = employees_df.merge(offices_df).groupby("country")['employeeNumber'].count().reset_index().rename(columns={'employeeNumber': '#employees'})
employees_per_country_df
# Out:
#      country  #employees
# 0  Australia           4
# 1     France           5
# 2      Japan           2
# 3         UK           2
# 4        USA          10

# %% [markdown]
# El promedio de los pagos de cada uno de los clientes de España (sin incluir aquellos que no poseen ningún pago).

# %%
query = sqla.text('SELECT customerName, AVG(amount) FROM customers INNER JOIN payments ON customers.customerNumber = payments.customerNumber WHERE customers.country LIKE "SPAIN" GROUP BY customerName')
customer_avg_payments_df = customers_df[customers_df["country"].str.contains("SPAIN", case=False, na=False)].merge(payments_df).groupby("customerName")["amount"].mean().reset_index().rename(columns={'amount': 'AVG(amount)'})
customer_avg_payments_df
# Out:
#                  customerName   AVG(amount)
# 0                 CAF Imports  23375.570000
# 1  Corrida Auto Replicas, Ltd  37480.030000
# 2          Enaco Distributors  22840.156667
# 3      Euro+ Shopping Channel  55056.844615
# 4  Iberia Gift Imports, Corp.  25493.925000

# %% [markdown]
# # **Parte 3**. Cliente de Python Firestore

# %% [markdown]
# En esta fase te conectarás a una base de datos no relacional de Firestore desde Python. Para ello utilizarás los módulos `credentials` y `firestore` de la biblioteca `firebase_admin`.

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore

# %% [markdown]
# El archivo `veterinary.json` almacena la clave privada para autenticar una cuenta y autorizar el acceso a los servicios de Firebase. A través de la función `Certificate()`, se regresa una credencial inicializada, que puedes utilizar para crear una nueva instancia de la aplicación. Después de eso, tu conexión a Firestore utilizará las reglas de seguridad establecidas para la base de datos y el usuario autenticado.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# import os
# DIR = "/content/drive/MyDrive/Colab Notebooks/MNA/TC4029 - Ciencia y analítica de datos/Semana 3/Actividad3_BD_Manipulacion"
# os.chdir(DIR)

# %%
cred = credentials.Certificate('veterinary.json')
firebase_admin.initialize_app(cred)
db = firestore.client()

# %% [markdown]
# 12.	Investiga cómo leer la colección `PET_OWNER` y mostrar su contenido en un dataframe. Asegúrate de incluir el id en el resultado

# %%
# Get all documents from the 'PET_OWNER' collection
# Retrieves all documents from the PET_OWNER collection in Firestore.
# It uses stream() which is more memory-efficient for large collections
docs = db.collection('PET_OWNER').stream()

# An empty list called data is created to store the data extracted from each documen
data = []

# Iterate over the documents and extract the data
for doc in docs:
    # Convert the current document to a Python dictionary
    doc_data = doc.to_dict()
    # Add a new key called 'id' to the dictionary with the document's ID
    doc_data['id'] = doc.id
    # Add the dictionary with the document data to the 'data' list
    data.append(doc_data)

# Create a Pandas DataFrame from the 'data' list
df = pd.DataFrame(data)

# Make the id column the index of the data frame
df.set_index('id', inplace=True)

# Display the DataFrame
df
# Out:
#                                             email         phone  \
# id
# 0D6yFSs2eu4nYwf2dnQ0                         None  555-454-3465
# 98357ufgjmWUxjnAuzbz    miles.trent@somewhere.com          None
# AFtZincSZxjC4Mcxf9Pf      liz.frier@somewhere.com  555-537-6543
# GYDixDwHjMyihjL8TmsM                         None  555-454-1243
# IpxTuB6FILhwQFcspLws  'marcha.downs@somewhere.com  555-537-8765
# QoXBfS1JdRp6BqgLzaAz                         None  555-454-2354
# eUtZ44lPRbSHXX04EDp7   nigel.melnik@somewhere.com  555-232-5678
# n2GG9rlfGOmE0P4TcU0T  richard.james@somewhere.com  555-537-7654
# pDlJlul8EJXO8FBJvFkN     jim.rogers@somewhere.com  555-232-3456
# tAlJ74xQ7tT4TUHwZgmH    mary.keenan@somewhere.com  555-232-4567
#
#                      ownerFirstName ownerLastName
# id
# 0D6yFSs2eu4nYwf2dnQ0            Sam        Taylor
# 98357ufgjmWUxjnAuzbz          Miles         Trent
# AFtZincSZxjC4Mcxf9Pf            Liz         Frier
# ...

# %%
# Terminate the Firebase app to release resources and prevent potential errors.
# This is important for proper resource management and ensures a clean Colab environment.
# It also avoids issues when re-initializing the app in the future.
firebase_admin.delete_app(firebase_admin.get_app())
